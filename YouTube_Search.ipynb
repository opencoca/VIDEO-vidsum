# %% [markdown]
# <a href="https://colab.research.google.com/github/opencoca/vidsum/blob/master/YouTube_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install youtube-search

# %%
from youtube_search import YoutubeSearch
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
youtube_search_string = "in 60 Seconds //" #@param {type:"string"}
results = YoutubeSearch(youtube_search_string, max_results=200).to_dict()
pp.pprint(results)
#@markdown For some reason you might to need to click in the next cell to see the output!?
# Out:
# [   {   'channel': 'ShivVZG',
#         'duration': '1:10',
#         'id': 'a6uF95av4LY',
#         'long_desc': None,
#         'publish_time': '1 year ago',
#         'thumbnails': [   'https://i.ytimg.com/vi/a6uF95av4LY/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBme7Yc6V0NiBa_g7ouLNvUum3Ccg',
#                           'https://i.ytimg.com/vi/a6uF95av4LY/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLCOOMl9FRGP_z8VgqycyMSIrVDMLg'],
#         'title': 'Roasting Every Middle School Student in 60 Seconds',
#         'url_suffix': '/watch?v=a6uF95av4LY',
#         'views': '3,773,335 views'},
#     {   'channel': 'The 60 Second Guy',
#         'duration': '1:23',
#         'id': 'lYly9rCfaSM',
#         'long_desc': None,
#         'publish_time': '8 months ago',
# ...

# %%
# Out:
# [   {   'channel': 'ShivVZG',
#         'duration': '1:10',
#         'id': 'a6uF95av4LY',
#         'long_desc': None,
#         'publish_time': '1 year ago',
#         'thumbnails': [   'https://i.ytimg.com/vi/a6uF95av4LY/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLBme7Yc6V0NiBa_g7ouLNvUum3Ccg',
#                           'https://i.ytimg.com/vi/a6uF95av4LY/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLCOOMl9FRGP_z8VgqycyMSIrVDMLg'],
#         'title': 'Roasting Every Middle School Student in 60 Seconds',
#         'url_suffix': '/watch?v=a6uF95av4LY',
#         'views': '3,773,335 views'},
#     {   'channel': 'The 60 Second Guy',
#         'duration': '1:23',
#         'id': 'lYly9rCfaSM',
#         'long_desc': None,
#         'publish_time': '8 months ago',
# ...

# %%
results.__len__()
# Out:
# 20
